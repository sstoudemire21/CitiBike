# %%
import pandas as pd

# %%
citi_201801 = pd.read_csv("../citibike/201801-citibike-tripdata.csv")
citi_201802 = pd.read_csv("../citibike/201802-citibike-tripdata.csv")
citi_201803 = pd.read_csv("../citibike/201803-citibike-tripdata.csv")
citi_201804 = pd.read_csv("../citibike/201804-citibike-tripdata.csv")
citi_201805 = pd.read_csv("../citibike/201805-citibike-tripdata.csv")
citi_201806 = pd.read_csv("../citibike/201806-citibike-tripdata.csv")
citi_201807 = pd.read_csv("../citibike/201807-citibike-tripdata.csv")
citi_201808 = pd.read_csv("../citibike/201808-citibike-tripdata.csv")
citi_201809 = pd.read_csv("../citibike/201809-citibike-tripdata.csv")
citi_201810 = pd.read_csv("../citibike/201810-citibike-tripdata.csv")
citi_201811 = pd.read_csv("../citibike/201811-citibike-tripdata.csv")
citi_201812 = pd.read_csv("../citibike/201812-citibike-tripdata.csv")

# %%
citi_frames = [citi_201801, citi_201802, citi_201803, citi_201804, citi_201805, citi_201806, citi_201807, citi_201808, citi_201809, citi_201810, citi_201811, citi_201812]
citi_result = pd.concat(citi_frames)
citi_result.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
citi_result.shape
# Out:
# (17548339, 15)

# %%
citi_result.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
citi_mem1 = pd.read_csv("../citi_membership/data-cZMp8.csv")
citi_mem2 = pd.read_csv("../citi_membership/data-FKjZg.csv")
citi_mem3 = pd.read_csv("../citi_membership/data-pRAtm.csv")
citi_mem4 = pd.read_csv("../citi_membership/data-tqNn6.csv")

# %%
data_frames = [citi_mem1, citi_mem2, citi_mem3, citi_mem4]
mem_result = pd.concat(data_frames)
mem_result.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/19                                              22145
# 1  1/2/19                                              38249
# 2  1/3/19                                              42181
# 3  1/4/19                                              44420
# 4  1/5/19                                              17636
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        44131
# 1                                        58975
# 2                                        62500
# 3                                        65739
# 4                                        24326
#
#    Total Annual Members (All Time)  \
# 0                           297823
# 1                           297908
# 2                           297976
# 3                           298017
# 4                           298048
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
mem_result.count()
# Out:
# Date                                                  365
# Trips over the past 24-hours (midnight to 11:59pm)    365
# Miles traveled today (midnight to 11:59 pm)           365
# Total Annual Members (All Time)                       365
# 24-Hour Passes Purchased (midnight to 11:59 pm)       365
# 3-Day Passes Purchased (midnight to 11:59 pm)         365
# dtype: int64

# %%
# Export to csv
citi_result.to_csv("../citibike/clean_data_2018.csv")
mem_result.to_csv("../citi_membership/clean_riders_2018.csv")
